# %% [markdown]
# # Métodos Específicos de Lista em Python

# %% [markdown]
# - list.append(valor)<br>
# Adiciona um valor ao final de uma lista

# %% [markdown]
# Uso:
#     vendas = [150, 320]
#     vendas.append(110)
# Resultado:
#     vendas = [150, 320, 110]

# %%
# append

lista = ['tefone', 'televisão', 'notebook', 'ventilador']
print(lista)

lista.append('impressora')
print(lista)
# Out:
# ['tefone', 'televisão', 'notebook', 'ventilador']
# ['tefone', 'televisão', 'notebook', 'ventilador', 'impressora']

# %% [markdown]
# - list.extend(lista2)<br>
# Adiciona todos os valores da lista2 na lista original

# %% [markdown]
# Uso:
#     vendas = [150, 320, 110, 450, 390, 370]
#     vendas_2semestre = [440, 470, 900, 1000, 1100, 1050]
#     vendas.extend(vendas_2semestre)
# Resultado:
#     vendas = [150, 320, 110, 450, 390, 370, 440, 470, 900, 1000, 1100, 1050]

# %%
# extend

produtos = ['café', 'suco', 'fruta', 'sacola de lixo']
print(produtos)

novos_produtos = ['mexerica', 'goiaba', 'manteiga']

produtos.extend(novos_produtos)

print(produtos)
# Out:
# ['café', 'suco', 'fruta', 'sacola de lixo']
# ['café', 'suco', 'fruta', 'sacola de lixo', 'mexerica', 'goiaba', 'manteiga']

# %% [markdown]
# - list.insert(posicao, valor)<br>
# Adiciona um valor em uma posição específica em uma lista. Não é recomendado usar a não ser que seja realmente necessário inserir em uma posição específica, porque o método append é mais eficiente.

# %% [markdown]
# Uso:
#     vendas = [150, 320]
#     vendas.insert(1, 110)
# Resultado:
#     vendas = [150, 110, 320]
# Obs:
#     Compare com o caso do list.append para ver a diferença

# %%
# insert

valores = [10, 20, 30, 40]
print(valores)

valores.insert(4, 50)
print(valores)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40, 50]

# %% [markdown]
# - list.remove(valor)<br>
# Remove o valor da lista (apenas a 1ª ocorrência, então caso haja 2 vezes o valor na lista, apenas a 1ª será removida). Além disso, dá um erro caso valor não exista dentro da lista.

# %% [markdown]
# Uso:
#     vendedores = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']
#     vendedores.remove('Maria')
# Resultado:
#     vendedores = ['João', 'Julia', 'Ana', 'Paulo', 'Marcus']

# %%
# remove

nomes = ['Paulo', 'Pedro', 'Alice']
print(nomes)

nomes.remove('Alice')
print(nomes)
# Out:
# ['Paulo', 'Pedro', 'Alice']
# ['Paulo', 'Pedro']

# %% [markdown]
# - list.pop(posicao)<br>
# Remove o item que está na posicao (índice) passado. Além disso, esse item é dado como resultado do pop, portanto pode ser armazenado em uma variável ou usado para outra coisa na mesma linha de código.

# %% [markdown]
# Uso:<br>
#     vendedores = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']<br>
#     vendedores.pop(2)<br>
# Resultado:<br>
#     vendedores = ['João', 'Julia', 'Ana', 'Paulo', 'Marcus']

# %%
# pop

vendedores = ['Marcio', 'Ana', 'Alex', 'Maria']
print(vendedores)

vendedores.pop(-1)
print(vendedores)
# Out:
# ['Marcio', 'Ana', 'Alex', 'Maria']
# ['Marcio', 'Ana', 'Alex']

# %% [markdown]
# - list.clear()<br>
# Remove todos os itens de uma lista

# %% [markdown]
# Uso:
#     vendedores = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']
#     vendedores.clear()
# Resultado:
#     vendedores = []

# %%
# clear

marcas = ['Kibon', 'Nestle', 'Garoto']
print(marcas)

marcas.clear()
print(marcas)
# Out:
# ['Kibon', 'Nestle', 'Garoto']
# []

# %% [markdown]
# - list.index(valor)<br>
# Retorna a posição do valor dentro da lista (em qual índice está o valor). Dá erro caso não haja o valor dentro da lista.

# %% [markdown]
# Uso:
#     vendedores = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus']
#     posicao_Joao = vendedores.index('João')
# Resultado:
#     posicao_Joao = 0

# %%
# index

flores = ['rosas', 'girassois', 'samambaias']
pos_rosas = flores.index('rosas')

print(flores)
print('A posição da rosa é o índice : {} '.format(pos_rosas))
# Out:
# ['rosas', 'girassois', 'samambaias']
# A posição da rosa é o índice : 1

# %% [markdown]
# - list.count(valor)<br>
# Retorna a quantidade de vezes que o valor aparece na lista

# %% [markdown]
# Uso:
#     vendedores = ['João', 'Julia', 'Maria', 'Ana', 'Paulo', 'Marcus', 'João']
#     qtde_Joao = vendedores.count('João')
# Resultado:
#     qtde_Joao = 2

# %%
# count

lojas = ['popeyes', 'mcdonalds', 'burguer king', 'popeyes', 'subway', 'popeyes']
print(lojas)

qtde_popeyes = lojas.count('popeyes')
print(qtde_popeyes)
# Out:
# ['popeyes', 'mcdonalds', 'burguer king', 'popeyes', 'subway', 'popeyes']
# 3

# %% [markdown]
# - list.sort(reverse=False)<br>
# Ordena os valores da lista em ordem crescente, ou alfabética, (reverse=False) ou decrescente (reverse=True).

# %% [markdown]
# Uso:
#     vendas = [150, 300, 190, 480]
#     vendas.sort(reverse=True)
# Resultado:
#     vendas = [480, 300, 190, 150]

# %%
# sort

meses = ['jan', 'fev', 'mar', 'abr', 'mai']
meses.sort()

meses_num = [1, 2, 3, 4, 5, 6]
meses_num.sort(reverse=True)

print(meses)
print(meses_num)
# Out:
# ['abr', 'fev', 'jan', 'mai', 'mar']
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# - list.reverse()<br>
# Inverte a ordem dos elementos de uma lista.

# %% [markdown]
# Uso:
#     vendas = [150, 300, 190, 480]
#     vendas.reverse()
# Resultado:
#     vendas = [480, 190, 300, 150]

# %%
# reverse

numeros = [275, 850, 555, 639, 600]
numeros.reverse()

print(numeros)
# Out:
# [600, 639, 555, 850, 275]

# %% [markdown]
# - list.copy()<br>
# Cria uma cópia da lista original. Outra opção é fazer lista2 = lista1[:]

# %% [markdown]
# Uso:
#     vendas = [150, 300, 190, 480]
#     vendas2 = vendas.copy()
# Resultado:
#     vendas2 = [150, 300, 190, 480]

# %%
# copy

dias = [7, 14, 21, 28, 35, 42, 49, 56]
dias_copia = dias.copy()

print(dias)
print(dias_copia)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56]
# [7, 14, 21, 28, 35, 42, 49, 56]
